# %%
# %run quick_validate.py
# Out:
# ...
# QUICK VALIDATION TEST - Per-IMEI Runtime Analysis
# ...
#
# 📅 Test Date: 2025-11-24
# ⏱️  Processing: Each IMEI separately with 1-minute filter
#
# 🔄 Loading ensemble model...
# 🔄 Loading ensemble models...
#   Loading GNN...
#   Loading XGBoost...
#   Loading LightGBM...
#   Loading meta-learner...
# ✅ All models loaded successfully!
#
# 📊 Meta-model weights:
#    GNN:      0.000
#    XGBoost:  1.522
#    LightGBM: -0.507
#   ⏱️  Model load time: 0.15s
#
# 📂 Scanning for IMEI files...
#   Found 91 IMEI files
#
# ...
# Processing IMEI 1/91: IMEI_864454070545367_20251124
# ...
#   📂 Loaded: 42,960 GPS points (0.07s)
#   ⏱️  Filtered to 1 minute: 57 points (0.001s)
#      Time range: 04:07:38 to 04:08:38
#      Sample GPS: lat=13.049838, lon=80.206899, speed=0
#   🔮 Predictions: 57 generated (0.07s)
#      Time per point: 1.3ms
#      Mean ETA: 17.16 minutes
#   ⏱️  Total IMEI processing time: 0.14s
#
# ...
# Processing IMEI 2/91: IMEI_864454070871953_20251124
# ...
#   📂 Loaded: 53,861 GPS points (1.07s)
# ...

# %%
import importlib
import validate
importlib.reload(validate)
from validate import ProductionValidator

validator = ProductionValidator(test_data_dir='../20to24nov')
metrics = validator.run()
# Out:
# ...
# PRODUCTION MODEL VALIDATION TEST
# ...
#
# 📅 Test Data: ../20to24nov
# 📊 Model: Ensemble (GNN + XGBoost + LightGBM)
# 🎯 Purpose: Final sanity check on unseen data
#
# 🔄 Loading production model...
# 🔄 Loading ensemble models...
#   Loading GNN...
#   Loading XGBoost...
#   Loading LightGBM...
#   Loading meta-learner...
# ✅ All models loaded successfully!
#
# 📊 Meta-model weights:
#    GNN:      0.000
#    XGBoost:  1.522
#    LightGBM: -0.507
# ✅ Model loaded successfully
#
# 📂 Loading unseen test data...
#   Found 360 CSV files
# Loading files: 100%|██████████| 360/360 [03:36<00:00,  1.67it/s]
#   Total GPS points: 17,276,318
#   Date range: 2025-01-11 15:27:08 to 2025-11-25 00:08:17
#
# 🔄 Preprocessing data...
#
# ...
# BUS ETA PREDICTION - UNIFIED PREPROCESSING PIPELINE
# ...
# Start time: 2026-01-05 04:38:16
#
# ...
# STEP 1: DATA CLEANING
# ...
# ✓ Removed 12,567,102 out-of-bounds points
# ✓ Remaining: 4,709,216 GPS records
#
# ...
# STEP 2: TRIP DETECTION
# ...
# ✓ Detected 501 valid trips
#
# ...
# STEP 3: ROUTE MATCHING
# ...
